# %% [markdown]
# <a href="https://colab.research.google.com/github/ritwiks9635/My_Neural_Network_Architecture/blob/main/Active_Learning_Review_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Review Classification using Active Learning**

# %% [markdown]
# ## Introduction
#
# With the growth of data-centric Machine Learning, Active Learning has grown in popularity
# amongst businesses and researchers. Active Learning seeks to progressively
# train ML models so that the resultant model requires lesser amount of training data to
# achieve competitive scores.
#
# The structure of an Active Learning pipeline involves a classifier and an oracle. The
# oracle is an annotator that cleans, selects, labels the data, and feeds it to the model
# when required. The oracle is a trained individual or a group of individuals that
# ensure consistency in labeling of new data.
#
# The process starts with annotating a small subset of the full dataset and training an
# initial model. The best model checkpoint is saved and then tested on a balanced test
# set. The test set must be carefully sampled because the full training process will be
# dependent on it. Once we have the initial evaluation scores, the oracle is tasked with
# labeling more samples; the number of data points to be sampled is usually determined by
# the business requirements. After that, the newly sampled data is added to the training
# set, and the training procedure repeats. This cycle continues until either an
# acceptable score is reached or some other business metric is met.
#
# This tutorial provides a basic demonstration of how Active Learning works by
# demonstrating a ratio-based (least confidence) sampling strategy that results in lower
# overall false positive and negative rates when compared to a model trained on the entire
# dataset. This sampling falls under the domain of *uncertainty sampling*, in which new
# datasets are sampled based on the uncertainty that the model outputs for the
# corresponding label. In our example, we compare our model's false positive and false
# negative rates and annotate the new data based on their ratio.
#
# Some other sampling techniques include:
#
# 1. [Committee sampling](https://www.researchgate.net/publication/51909346_Committee-Based_Sample_Selection_for_Probabilistic_Classifiers):
# Using multiple models to vote for the best data points to be sampled
# 2. [Entropy reduction](https://www.researchgate.net/publication/51909346_Committee-Based_Sample_Selection_for_Probabilistic_Classifiers):
# Sampling according to an entropy threshold, selecting more of the samples that produce the highest entropy score.
# 3. [Minimum margin based sampling](https://arxiv.org/abs/1906.00025v1):
# Selects data points closest to the decision boundary

# %%
import re
import string
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt

# %%
dataset = tfds.load(
    "imdb_reviews",
    split = "train + test",
    as_supervised = True,
    batch_size = -1,
    shuffle_files = False)

reviews, labels = tfds.as_numpy(dataset)
print("total example is :: ", reviews.shape[0])
# Out:
# Downloading and preparing dataset 80.23 MiB (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteYU65SR/imdb_reviews-train.tfrecord…
# Generating test examples...:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteYU65SR/imdb_reviews-test.tfrecord*…
# Generating unsupervised examples...:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteYU65SR/imdb_reviews-unsupervised.t…
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.
# total example is ::  50000

# %%
reviews[1]
# Out:
# b'I have been known to fall asleep during films, but this is usually due to a combination of things including, really tired, being warm and comfortable on the sette and having just eaten a lot. However on this occasion I fell asleep because the film was rubbish. The plot development was constant. Constantly slow and boring. Things seemed to happen, but with no explanation of what was causing them or why. I admit, I may have missed part of the film, but i watched the majority of it and everything just seemed to happen of its own accord without any real concern for anything else. I cant recommend this film at all.'

# %% [markdown]
# Active learning starts with labeling a subset of data.
# For the ratio sampling technique that we will be using, we will need well-balanced training,
# validation and testing splits.

# %%
val_split = 2500
test_split = 2500
train_split = 7500

# Separating the negative and positive samples for manual stratification
x_positives, y_positives = reviews[labels == 1], labels[labels == 1]
x_negatives, y_negatives = reviews[labels == 0], labels[labels == 0]

# Creating training, validation and testing splits
x_val, y_val = (
    tf.concat((x_positives[:val_split], x_negatives[:val_split]), 0),
    tf.concat((y_positives[:val_split], y_negatives[:val_split]), 0),
)
x_test, y_test = (
    tf.concat(
        (
            x_positives[val_split : val_split + test_split],
            x_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split : val_split + test_split],
            y_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
)
x_train, y_train = (
    tf.concat(
        (
            x_positives[val_split + test_split : val_split + test_split + train_split],
            x_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split + test_split : val_split + test_split + train_split],
            y_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
)

# Remaining pool of samples are stored separately. These are only labeled as and when required
x_pool_positives, y_pool_positives = (
    x_positives[val_split + test_split + train_split :],
    y_positives[val_split + test_split + train_split :],
)
x_pool_negatives, y_pool_negatives = (
    x_negatives[val_split + test_split + train_split :],
    y_negatives[val_split + test_split + train_split :],
)

# %%
# Creating TF Datasets for faster prefetching and parallelization
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))

pool_negatives = tf.data.Dataset.from_tensor_slices(
    (x_pool_negatives, y_pool_negatives))
pool_positives = tf.data.Dataset.from_tensor_slices(
    (x_pool_positives, y_pool_positives))

print(f"Initial training set size: {len(train_dataset)}")
print(f"Validation set size: {len(val_dataset)}")
print(f"Testing set size: {len(test_dataset)}")
print(f"Unlabeled negative pool: {len(pool_negatives)}")
print(f"Unlabeled positive pool: {len(pool_positives)}")
# Out:
# Initial training set size: 15000
# Validation set size: 5000
# Testing set size: 5000
# Unlabeled negative pool: 12500
# Unlabeled positive pool: 12500

# %% [markdown]
# ### Fitting the `TextVectorization` layer
#
# Since we are working with text data, we will need to encode the text strings as vectors which
# would then be passed through an `Embedding` layer. To make this tokenization process
# faster, we use the `map()` function with its parallelization functionality.

# %%
def custom_standardization(input_data):
    lowercase = tf.strings.lower(input_data)
    stripped_html = tf.strings.regex_replace(lowercase, "<br />", " ")
    return tf.strings.regex_replace(
        stripped_html, f"[{re.escape(string.punctuation)}]", "")



vectorizer = tf.keras.layers.TextVectorization(
    3000, standardize = custom_standardization, output_sequence_length = 150)


vectorizer.adapt(train_dataset.map(lambda x, y : x, num_parallel_calls = tf.data.AUTOTUNE).batch(256))


def vectorize_text(text, label):
    text = vectorizer(text)
    return text, label

train_dataset = train_dataset.map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
).prefetch(tf.data.AUTOTUNE)
pool_negatives = pool_negatives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)
pool_positives = pool_positives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)

val_dataset = val_dataset.batch(256).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)
test_dataset = test_dataset.batch(256).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)

# %% [markdown]
# ## Creating Helper Functions

# %%
# Helper function for merging new history objects with older ones
def append_history(losses, val_losses, accuracy, val_accuracy, history):
    losses = losses + history.history["loss"]
    val_losses = val_losses + history.history["val_loss"]
    accuracy = accuracy + history.history["binary_accuracy"]
    val_accuracy = val_accuracy + history.history["val_binary_accuracy"]
    return losses, val_losses, accuracy, val_accuracy


# Plotter function
def plot_history(losses, val_losses, accuracies, val_accuracies):
    plt.plot(losses)
    plt.plot(val_losses)
    plt.legend(["train_loss", "val_loss"])
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.show()

    plt.plot(accuracies)
    plt.plot(val_accuracies)
    plt.legend(["train_accuracy", "val_accuracy"])
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.show()

# %% [markdown]
# ## Creating the Model
#
# We create a small bidirectional LSTM model. When using Active Learning, you should make sure
# that the model architecture is capable of overfitting to the initial data.
# Overfitting gives a strong hint that the model will have enough capacity for
# future, unseen data.

# %%
def create_model():
    model = keras.Sequential(
        [
            layers.Input(shape = (150,)),
            layers.Embedding(input_dim = 3000, output_dim = 128),
            layers.Bidirectional(layers.LSTM(32, return_sequences = True)),
            layers.GlobalMaxPooling1D(),
            layers.Dense(20, activation = "relu"),
            layers.Dropout(0.5),
            layers.Dense(1, activation = "sigmoid")
        ]
    )
    model.summary()
    return model

# %% [markdown]
# ## Training on the entire dataset
#
# To show the effectiveness of Active Learning, we will first train the model on the entire
# dataset containing 40,000 labeled samples. This model will be used for comparison later.

# %%
def train_full_model(full_train_dataset, val_dataset, test_dataset):
    model = create_model()
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives(),
        ],
    )

    # We will save the best model at every epoch and load the best one for evaluation on the test set
    history = model.fit(
        full_train_dataset.batch(256),
        epochs=20,
        validation_data=val_dataset,
        callbacks=[
            keras.callbacks.EarlyStopping(patience=4, verbose=1),
            keras.callbacks.ModelCheckpoint(
                "FullModelCheckpoint.h5", verbose=1, save_best_only=True
            ),
        ],
    )

    # Plot history
    plot_history(
        history.history["loss"],
        history.history["val_loss"],
        history.history["binary_accuracy"],
        history.history["val_binary_accuracy"],
    )

    # Loading the best checkpoint
    model = keras.models.load_model("FullModelCheckpoint.h5")

    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)
    return model

# %%
# Sampling the full train dataset to train on
full_train_dataset = (
    train_dataset.concatenate(pool_positives)
    .concatenate(pool_negatives)
    .cache()
    .shuffle(20000)
)

# Training the full model
full_dataset_model = train_full_model(full_train_dataset, val_dataset, test_dataset)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 128)          384000
#
#  bidirectional (Bidirection  (None, 150, 64)           41216
#  al)
#
#  global_max_pooling1d (Glob  (None, 64)                0
#  alMaxPooling1D)
#
#  dense (Dense)               (None, 20)                1300
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 426537 (1.63 MB)
# Trainable params: 426537 (1.63 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 157/157 [==============================] - ETA: 0s - loss: 0.6419 - binary_accuracy: 0.6448 - false_negatives: 6147.0000 - false_positives: 8062.0000
# Epoch 1: val_loss improved from inf to 0.59041, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 26s 84ms/step - loss: 0.6419 - binary_accuracy: 0.6448 - false_negatives: 6147.0000 - false_positives: 8062.0000 - val_loss: 0.5904 - val_binary_accuracy: 0.6832 - val_false_negatives: 1477.0000 - val_false_positives: 107.0000
# Epoch 2/20
#   2/157 [..............................] - ETA: 11s - loss: 0.6448 - binary_accuracy: 0.6680 - false_negatives: 107.0000 - false_positives: 63.0000
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 157/157 [==============================] - ETA: 0s - loss: 0.4534 - binary_accuracy: 0.8060 - false_negatives: 3395.0000 - false_positives: 4364.0000
# Epoch 2: val_loss improved from 0.59041 to 0.48832, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 4s 26ms/step - loss: 0.4534 - binary_accuracy: 0.8060 - false_negatives: 3395.0000 - false_positives: 4364.0000 - val_loss: 0.4883 - val_binary_accuracy: 0.7804 - val_false_negatives: 979.0000 - val_false_positives: 119.0000
# Epoch 3/20
# 157/157 [==============================] - ETA: 0s - loss: 0.3737 - binary_accuracy: 0.8486 - false_negatives: 2792.0000 - false_positives: 3262.0000
# Epoch 3: val_loss improved from 0.48832 to 0.35939, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 3s 20ms/step - loss: 0.3737 - binary_accuracy: 0.8486 - false_negatives: 2792.0000 - false_positives: 3262.0000 - val_loss: 0.3594 - val_binary_accuracy: 0.8442 - val_false_negatives: 519.0000 - val_false_positives: 260.0000
# Epoch 4/20
# 157/157 [==============================] - ETA: 0s - loss: 0.3389 - binary_accuracy: 0.8651 - false_negatives: 2532.0000 - false_positives: 2865.0000
# Epoch 4: val_loss improved from 0.35939 to 0.34023, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 4s 24ms/step - loss: 0.3389 - binary_accuracy: 0.8651 - false_negatives: 2532.0000 - false_positives: 2865.0000 - val_loss: 0.3402 - val_binary_accuracy: 0.8492 - val_false_negatives: 283.0000 - val_false_positives: 471.0000
# Epoch 5/20
# 157/157 [==============================] - ETA: 0s - loss: 0.3196 - binary_accuracy: 0.8740 - false_negatives: 2385.0000 - false_positives: 2657.0000
# Epoch 5: val_loss did not improve from 0.34023
# 157/157 [==============================] - 3s 22ms/step - loss: 0.3196 - binary_accuracy: 0.8740 - false_negatives: 2385.0000 - false_positives: 2657.0000 - val_loss: 0.4126 - val_binary_accuracy: 0.8314 - val_false_negatives: 649.0000 - val_false_positives: 194.0000
# Epoch 6/20
# 157/157 [==============================] - ETA: 0s - loss: 0.3079 - binary_accuracy: 0.8788 - false_negatives: 2275.0000 - false_positives: 2571.0000
# Epoch 6: val_loss did not improve from 0.34023
# 157/157 [==============================] - 3s 19ms/step - loss: 0.3079 - binary_accuracy: 0.8788 - false_negatives: 2275.0000 - false_positives: 2571.0000 - val_loss: 0.3583 - val_binary_accuracy: 0.8472 - val_false_negatives: 530.0000 - val_false_positives: 234.0000
# Epoch 7/20
# 157/157 [==============================] - ETA: 0s - loss: 0.2941 - binary_accuracy: 0.8844 - false_negatives: 2131.0000 - false_positives: 2493.0000
# Epoch 7: val_loss improved from 0.34023 to 0.33547, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 3s 20ms/step - loss: 0.2941 - binary_accuracy: 0.8844 - false_negatives: 2131.0000 - false_positives: 2493.0000 - val_loss: 0.3355 - val_binary_accuracy: 0.8524 - val_false_negatives: 398.0000 - val_false_positives: 340.0000
# Epoch 8/20
# 157/157 [==============================] - ETA: 0s - loss: 0.2860 - binary_accuracy: 0.8904 - false_negatives: 2056.0000 - false_positives: 2327.0000
# Epoch 8: val_loss improved from 0.33547 to 0.32464, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 4s 24ms/step - loss: 0.2860 - binary_accuracy: 0.8904 - false_negatives: 2056.0000 - false_positives: 2327.0000 - val_loss: 0.3246 - val_binary_accuracy: 0.8592 - val_false_negatives: 339.0000 - val_false_positives: 365.0000
# Epoch 9/20
# 157/157 [==============================] - ETA: 0s - loss: 0.2742 - binary_accuracy: 0.8949 - false_negatives: 1924.0000 - false_positives: 2278.0000
# Epoch 9: val_loss did not improve from 0.32464
# 157/157 [==============================] - 3s 18ms/step - loss: 0.2742 - binary_accuracy: 0.8949 - false_negatives: 1924.0000 - false_positives: 2278.0000 - val_loss: 0.3312 - val_binary_accuracy: 0.8546 - val_false_negatives: 269.0000 - val_false_positives: 458.0000
# Epoch 10/20
# 157/157 [==============================] - ETA: 0s - loss: 0.2624 - binary_accuracy: 0.9002 - false_negatives: 1857.0000 - false_positives: 2137.0000
# Epoch 10: val_loss did not improve from 0.32464
# 157/157 [==============================] - 6s 35ms/step - loss: 0.2624 - binary_accuracy: 0.9002 - false_negatives: 1857.0000 - false_positives: 2137.0000 - val_loss: 0.3846 - val_binary_accuracy: 0.8418 - val_false_negatives: 169.0000 - val_false_positives: 622.0000
# Epoch 11/20
# 157/157 [==============================] - ETA: 0s - loss: 0.2551 - binary_accuracy: 0.9056 - false_negatives: 1782.0000 - false_positives: 1996.0000
# Epoch 11: val_loss did not improve from 0.32464
# 157/157 [==============================] - 3s 20ms/step - loss: 0.2551 - binary_accuracy: 0.9056 - false_negatives: 1782.0000 - false_positives: 1996.0000 - val_loss: 0.3762 - val_binary_accuracy: 0.8492 - val_false_negatives: 209.0000 - val_false_positives: 545.0000
# Epoch 12/20
# 157/157 [==============================] - ETA: 0s - loss: 0.2431 - binary_accuracy: 0.9079 - false_negatives: 1729.0000 - false_positives: 1957.0000
# Epoch 12: val_loss did not improve from 0.32464
# 157/157 [==============================] - 3s 19ms/step - loss: 0.2431 - binary_accuracy: 0.9079 - false_negatives: 1729.0000 - false_positives: 1957.0000 - val_loss: 0.3594 - val_binary_accuracy: 0.8518 - val_false_negatives: 448.0000 - val_false_positives: 293.0000
# Epoch 12: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.33246809244155884, 'binary_accuracy': 0.8587999939918518, 'false_negatives': 352.0, 'false_positives': 354.0}
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Training via Active Learning
#
# The general process we follow when performing Active Learning is demonstrated below:
#
# ![Active Learning](https://i.imgur.com/dmNKusp.png)
#
# The pipeline can be summarized in five parts:
#
# 1. Sample and annotate a small, balanced training dataset
# 2. Train the model on this small subset
# 3. Evaluate the model on a balanced testing set
# 4. If the model satisfies the business criteria, deploy it in a real time setting
# 5. If it doesn't pass the criteria, sample a few more samples according to the ratio of
# false positives and negatives, add them to the training set and repeat from step 2 till
# the model passes the tests or till all available data is exhausted.
#
# For the code below, we will perform sampling using the following formula:<br/>
#
# ![Ratio Sampling](https://i.imgur.com/LyZEiZL.png)
#
# Active Learning techniques use callbacks extensively for progress tracking. We will be
# using model checkpointing and early stopping for this example. The `patience` parameter
# for Early Stopping can help minimize overfitting and the time required. We have set it
# `patience=4` for now but since the model is robust, we can increase the patience level if
# desired.
#
# Note: We are not loading the checkpoint after the first training iteration. In my
# experience working on Active Learning techniques, this helps the model probe the
# newly formed loss landscape. Even if the model fails to improve in the second iteration,
# we will still gain insight about the possible future false positive and negative rates.
# This will help us sample a better set in the next iteration where the model will have a
# greater chance to improve.

# %%
def train_active_learning_models(
    train_dataset,
    pool_negatives,
    pool_positives,
    val_dataset,
    test_dataset,
    num_iterations=3,
    sampling_size=5000,
):

    # Creating lists for storing metrics
    losses, val_losses, accuracies, val_accuracies = [], [], [], []

    model = create_model()
    # We will monitor the false positives and false negatives predicted by our model
    # These will decide the subsequent sampling ratio for every Active Learning loop
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives(),
        ],
    )

    # Defining checkpoints.
    # The checkpoint callback is reused throughout the training since it only saves the best overall model.
    checkpoint = keras.callbacks.ModelCheckpoint(
        "AL_Model.h5", save_best_only=True, verbose=1
    )
    # Here, patience is set to 4. This can be set higher if desired.
    early_stopping = keras.callbacks.EarlyStopping(patience=4, verbose=1)

    print(f"Starting to train with {len(train_dataset)} samples")
    # Initial fit with a small subset of the training set
    history = model.fit(
        train_dataset.cache().shuffle(20000).batch(256),
        epochs=20,
        validation_data=val_dataset,
        callbacks=[checkpoint, early_stopping],
    )

    # Appending history
    losses, val_losses, accuracies, val_accuracies = append_history(
        losses, val_losses, accuracies, val_accuracies, history
    )

    for iteration in range(num_iterations):
        # Getting predictions from previously trained model
        predictions = model.predict(test_dataset)

        # Generating labels from the output probabilities
        rounded = tf.where(tf.greater(predictions, 0.5), 1, 0)

        # Evaluating the number of zeros and ones incorrrectly classified
        _, _, false_negatives, false_positives = model.evaluate(test_dataset, verbose=0)

        print("-" * 100)
        print(
            f"Number of zeros incorrectly classified: {false_negatives}, Number of ones incorrectly classified: {false_positives}"
        )

        # This technique of Active Learning demonstrates ratio based sampling where
        # Number of ones/zeros to sample = Number of ones/zeros incorrectly classified / Total incorrectly classified
        if false_negatives != 0 and false_positives != 0:
            total = false_negatives + false_positives
            sample_ratio_ones, sample_ratio_zeros = (
                false_positives / total,
                false_negatives / total,
            )
        # In the case where all samples are correctly predicted, we can sample both classes equally
        else:
            sample_ratio_ones, sample_ratio_zeros = 0.5, 0.5

        print(
            f"Sample ratio for positives: {sample_ratio_ones}, Sample ratio for negatives:{sample_ratio_zeros}"
        )

        # Sample the required number of ones and zeros
        sampled_dataset = pool_negatives.take(
            int(sample_ratio_zeros * sampling_size)
        ).concatenate(pool_positives.take(int(sample_ratio_ones * sampling_size)))

        # Skip the sampled data points to avoid repetition of sample
        pool_negatives = pool_negatives.skip(int(sample_ratio_zeros * sampling_size))
        pool_positives = pool_positives.skip(int(sample_ratio_ones * sampling_size))

        # Concatenating the train_dataset with the sampled_dataset
        train_dataset = train_dataset.concatenate(sampled_dataset).prefetch(
            tf.data.AUTOTUNE
        )

        print(f"Starting training with {len(train_dataset)} samples")
        print("-" * 100)

        # We recompile the model to reset the optimizer states and retrain the model
        model.compile(
            loss="binary_crossentropy",
            optimizer="rmsprop",
            metrics=[
                keras.metrics.BinaryAccuracy(),
                keras.metrics.FalseNegatives(),
                keras.metrics.FalsePositives(),
            ],
        )
        history = model.fit(
            train_dataset.cache().shuffle(20000).batch(256),
            validation_data=val_dataset,
            epochs=20,
            callbacks=[
                checkpoint,
                keras.callbacks.EarlyStopping(patience=4, verbose=1),
            ],
        )

        # Appending the history
        losses, val_losses, accuracies, val_accuracies = append_history(
            losses, val_losses, accuracies, val_accuracies, history
        )

        # Loading the best model from this training loop
        model = keras.models.load_model("AL_Model.h5")

    # Plotting the overall history and evaluating the final model
    plot_history(losses, val_losses, accuracies, val_accuracies)
    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)

    return model


active_learning_model = train_active_learning_models(
    train_dataset, pool_negatives, pool_positives, val_dataset, test_dataset
)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 150, 128)          384000
#
#  bidirectional_1 (Bidirecti  (None, 150, 64)           41216
#  onal)
#
#  global_max_pooling1d_1 (Gl  (None, 64)                0
#  obalMaxPooling1D)
#
#  dense_2 (Dense)             (None, 20)                1300
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_3 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 426537 (1.63 MB)
# Trainable params: 426537 (1.63 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Starting to train with 15000 samples
# Epoch 1/20
# 59/59 [==============================] - ETA: 0s - loss: 0.6888 - binary_accuracy: 0.5498 - false_negatives_1: 3114.0000 - false_positives_1: 3639.0000
# Epoch 1: val_loss improved from inf to 0.67568, saving model to AL_Model.h5
# 59/59 [==============================] - 11s 88ms/step - loss: 0.6888 - binary_accuracy: 0.5498 - false_negatives_1: 3114.0000 - false_positives_1: 3639.0000 - val_loss: 0.6757 - val_binary_accuracy: 0.6682 - val_false_negatives_1: 339.0000 - val_false_positives_1: 1320.0000
# Epoch 2/20
# 59/59 [==============================] - ETA: 0s - loss: 0.6213 - binary_accuracy: 0.6778 - false_negatives_1: 2198.0000 - false_positives_1: 2635.0000
# Epoch 2: val_loss improved from 0.67568 to 0.62068, saving model to AL_Model.h5
# 59/59 [==============================] - 3s 49ms/step - loss: 0.6213 - binary_accuracy: 0.6778 - false_negatives_1: 2198.0000 - false_positives_1: 2635.0000 - val_loss: 0.6207 - val_binary_accuracy: 0.6312 - val_false_negatives_1: 1809.0000 - val_false_positives_1: 35.0000
# Epoch 3/20
# 59/59 [==============================] - ETA: 0s - loss: 0.4877 - binary_accuracy: 0.7876 - false_negatives_1: 1545.0000 - false_positives_1: 1641.0000
# Epoch 3: val_loss improved from 0.62068 to 0.43398, saving model to AL_Model.h5
# 59/59 [==============================] - 3s 42ms/step - loss: 0.4877 - binary_accuracy: 0.7876 - false_negatives_1: 1545.0000 - false_positives_1: 1641.0000 - val_loss: 0.4340 - val_binary_accuracy: 0.8094 - val_false_negatives_1: 259.0000 - val_false_positives_1: 694.0000
# Epoch 4/20
# 59/59 [==============================] - ETA: 0s - loss: 0.4255 - binary_accuracy: 0.8237 - false_negatives_1: 1286.0000 - false_positives_1: 1358.0000
# Epoch 4: val_loss improved from 0.43398 to 0.38842, saving model to AL_Model.h5
# 59/59 [==============================] - 2s 28ms/step - loss: 0.4255 - binary_accuracy: 0.8237 - false_negatives_1: 1286.0000 - false_positives_1: 1358.0000 - val_loss: 0.3884 - val_binary_accuracy: 0.8288 - val_false_negatives_1: 290.0000 - val_false_positives_1: 566.0000
# Epoch 5/20
# 59/59 [==============================] - ETA: 0s - loss: 0.3875 - binary_accuracy: 0.8473 - false_negatives_1: 1080.0000 - false_positives_1: 1211.0000
# Epoch 5: val_loss improved from 0.38842 to 0.36493, saving model to AL_Model.h5
# 59/59 [==============================] - 2s 35ms/step - loss: 0.3875 - binary_accuracy: 0.8473 - false_negatives_1: 1080.0000 - false_positives_1: 1211.0000 - val_loss: 0.3649 - val_binary_accuracy: 0.8418 - val_false_negatives_1: 461.0000 - val_false_positives_1: 330.0000
# Epoch 6/20
# 59/59 [==============================] - ETA: 0s - loss: 0.3500 - binary_accuracy: 0.8675 - false_negatives_1: 933.0000 - false_positives_1: 1054.0000
# Epoch 6: val_loss did not improve from 0.36493
# 59/59 [==============================] - 2s 38ms/step - loss: 0.3500 - binary_accuracy: 0.8675 - false_negatives_1: 933.0000 - false_positives_1: 1054.0000 - val_loss: 0.3704 - val_binary_accuracy: 0.8410 - val_false_negatives_1: 246.0000 - val_false_positives_1: 549.0000
# Epoch 7/20
# 59/59 [==============================] - ETA: 0s - loss: 0.3268 - binary_accuracy: 0.8755 - false_negatives_1: 886.0000 - false_positives_1: 981.0000
# Epoch 7: val_loss did not improve from 0.36493
# 59/59 [==============================] - 1s 25ms/step - loss: 0.3268 - binary_accuracy: 0.8755 - false_negatives_1: 886.0000 - false_positives_1: 981.0000 - val_loss: 0.3651 - val_binary_accuracy: 0.8442 - val_false_negatives_1: 343.0000 - val_false_positives_1: 436.0000
# Epoch 8/20
# 59/59 [==============================] - ETA: 0s - loss: 0.3188 - binary_accuracy: 0.8798 - false_negatives_1: 881.0000 - false_positives_1: 922.0000
# Epoch 8: val_loss did not improve from 0.36493
# 59/59 [==============================] - 1s 25ms/step - loss: 0.3188 - binary_accuracy: 0.8798 - false_negatives_1: 881.0000 - false_positives_1: 922.0000 - val_loss: 0.3795 - val_binary_accuracy: 0.8410 - val_false_negatives_1: 471.0000 - val_false_positives_1: 324.0000
# Epoch 9/20
# 57/59 [===========================>..] - ETA: 0s - loss: 0.2944 - binary_accuracy: 0.8941 - false_negatives_1: 755.0000 - false_positives_1: 791.0000
# Epoch 9: val_loss did not improve from 0.36493
# 59/59 [==============================] - 1s 24ms/step - loss: 0.2943 - binary_accuracy: 0.8937 - false_negatives_1: 770.0000 - false_positives_1: 825.0000 - val_loss: 0.3683 - val_binary_accuracy: 0.8428 - val_false_negatives_1: 335.0000 - val_false_positives_1: 451.0000
# Epoch 9: early stopping
# 20/20 [==============================] - 2s 13ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 351.0, Number of ones incorrectly classified: 440.0
# Sample ratio for positives: 0.5562579013906448, Sample ratio for negatives:0.44374209860935526
# Starting training with 19999 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 79/79 [==============================] - ETA: 0s - loss: 0.3234 - binary_accuracy: 0.8774 - false_negatives_2: 1239.0000 - false_positives_2: 1212.0000
# Epoch 1: val_loss did not improve from 0.36493
# 79/79 [==============================] - 13s 78ms/step - loss: 0.3234 - binary_accuracy: 0.8774 - false_negatives_2: 1239.0000 - false_positives_2: 1212.0000 - val_loss: 0.3839 - val_binary_accuracy: 0.8454 - val_false_negatives_2: 427.0000 - val_false_positives_2: 346.0000
# Epoch 2/20
# 79/79 [==============================] - ETA: 0s - loss: 0.3015 - binary_accuracy: 0.8875 - false_negatives_2: 1080.0000 - false_positives_2: 1169.0000
# Epoch 2: val_loss did not improve from 0.36493
# 79/79 [==============================] - 4s 50ms/step - loss: 0.3015 - binary_accuracy: 0.8875 - false_negatives_2: 1080.0000 - false_positives_2: 1169.0000 - val_loss: 0.3859 - val_binary_accuracy: 0.8328 - val_false_negatives_2: 187.0000 - val_false_positives_2: 649.0000
# Epoch 3/20
# 79/79 [==============================] - ETA: 0s - loss: 0.2787 - binary_accuracy: 0.8966 - false_negatives_2: 1022.0000 - false_positives_2: 1045.0000
# Epoch 3: val_loss did not improve from 0.36493
# 79/79 [==============================] - 2s 28ms/step - loss: 0.2787 - binary_accuracy: 0.8966 - false_negatives_2: 1022.0000 - false_positives_2: 1045.0000 - val_loss: 0.5621 - val_binary_accuracy: 0.7722 - val_false_negatives_2: 1018.0000 - val_false_positives_2: 121.0000
# Epoch 4/20
# 79/79 [==============================] - ETA: 0s - loss: 0.2746 - binary_accuracy: 0.8985 - false_negatives_2: 995.0000 - false_positives_2: 1034.0000
# Epoch 4: val_loss did not improve from 0.36493
# 79/79 [==============================] - 2s 28ms/step - loss: 0.2746 - binary_accuracy: 0.8985 - false_negatives_2: 995.0000 - false_positives_2: 1034.0000 - val_loss: 0.3870 - val_binary_accuracy: 0.8396 - val_false_negatives_2: 511.0000 - val_false_positives_2: 291.0000
# Epoch 5/20
# 79/79 [==============================] - ETA: 0s - loss: 0.2540 - binary_accuracy: 0.9071 - false_negatives_2: 913.0000 - false_positives_2: 944.0000
# Epoch 5: val_loss did not improve from 0.36493
# 79/79 [==============================] - 2s 23ms/step - loss: 0.2540 - binary_accuracy: 0.9071 - false_negatives_2: 913.0000 - false_positives_2: 944.0000 - val_loss: 0.3870 - val_binary_accuracy: 0.8366 - val_false_negatives_2: 536.0000 - val_false_positives_2: 281.0000
# Epoch 5: early stopping
# 20/20 [==============================] - 1s 12ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 490.0, Number of ones incorrectly classified: 329.0
# Sample ratio for positives: 0.4017094017094017, Sample ratio for negatives:0.5982905982905983
# Starting training with 24998 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 98/98 [==============================] - ETA: 0s - loss: 0.3783 - binary_accuracy: 0.8493 - false_negatives_3: 1778.0000 - false_positives_3: 1988.0000
# Epoch 1: val_loss did not improve from 0.36493
# 98/98 [==============================] - 17s 96ms/step - loss: 0.3783 - binary_accuracy: 0.8493 - false_negatives_3: 1778.0000 - false_positives_3: 1988.0000 - val_loss: 0.3773 - val_binary_accuracy: 0.8330 - val_false_negatives_3: 190.0000 - val_false_positives_3: 645.0000
# Epoch 2/20
# 98/98 [==============================] - ETA: 0s - loss: 0.3459 - binary_accuracy: 0.8634 - false_negatives_3: 1601.0000 - false_positives_3: 1813.0000
# Epoch 2: val_loss improved from 0.36493 to 0.35272, saving model to AL_Model.h5
# 98/98 [==============================] - 4s 39ms/step - loss: 0.3459 - binary_accuracy: 0.8634 - false_negatives_3: 1601.0000 - false_positives_3: 1813.0000 - val_loss: 0.3527 - val_binary_accuracy: 0.8464 - val_false_negatives_3: 273.0000 - val_false_positives_3: 495.0000
# Epoch 3/20
# 98/98 [==============================] - ETA: 0s - loss: 0.3261 - binary_accuracy: 0.8738 - false_negatives_3: 1509.0000 - false_positives_3: 1645.0000
# Epoch 3: val_loss improved from 0.35272 to 0.34983, saving model to AL_Model.h5
# 98/98 [==============================] - 3s 28ms/step - loss: 0.3261 - binary_accuracy: 0.8738 - false_negatives_3: 1509.0000 - false_positives_3: 1645.0000 - val_loss: 0.3498 - val_binary_accuracy: 0.8476 - val_false_negatives_3: 461.0000 - val_false_positives_3: 301.0000
# Epoch 4/20
# 98/98 [==============================] - ETA: 0s - loss: 0.3068 - binary_accuracy: 0.8824 - false_negatives_3: 1409.0000 - false_positives_3: 1532.0000
# Epoch 4: val_loss did not improve from 0.34983
# 98/98 [==============================] - 2s 25ms/step - loss: 0.3068 - binary_accuracy: 0.8824 - false_negatives_3: 1409.0000 - false_positives_3: 1532.0000 - val_loss: 0.3514 - val_binary_accuracy: 0.8460 - val_false_negatives_3: 235.0000 - val_false_positives_3: 535.0000
# Epoch 5/20
# 98/98 [==============================] - ETA: 0s - loss: 0.2968 - binary_accuracy: 0.8862 - false_negatives_3: 1387.0000 - false_positives_3: 1458.0000
# Epoch 5: val_loss improved from 0.34983 to 0.33714, saving model to AL_Model.h5
# 98/98 [==============================] - 2s 22ms/step - loss: 0.2968 - binary_accuracy: 0.8862 - false_negatives_3: 1387.0000 - false_positives_3: 1458.0000 - val_loss: 0.3371 - val_binary_accuracy: 0.8550 - val_false_negatives_3: 314.0000 - val_false_positives_3: 411.0000
# Epoch 6/20
# 98/98 [==============================] - ETA: 0s - loss: 0.2823 - binary_accuracy: 0.8939 - false_negatives_3: 1292.0000 - false_positives_3: 1360.0000
# Epoch 6: val_loss did not improve from 0.33714
# 98/98 [==============================] - 3s 32ms/step - loss: 0.2823 - binary_accuracy: 0.8939 - false_negatives_3: 1292.0000 - false_positives_3: 1360.0000 - val_loss: 0.4256 - val_binary_accuracy: 0.8132 - val_false_negatives_3: 788.0000 - val_false_positives_3: 146.0000
# Epoch 7/20
# 97/98 [============================>.] - ETA: 0s - loss: 0.2747 - binary_accuracy: 0.8990 - false_negatives_3: 1264.0000 - false_positives_3: 1245.0000
# Epoch 7: val_loss did not improve from 0.33714
# 98/98 [==============================] - 3s 30ms/step - loss: 0.2745 - binary_accuracy: 0.8990 - false_negatives_3: 1270.0000 - false_positives_3: 1256.0000 - val_loss: 0.3533 - val_binary_accuracy: 0.8510 - val_false_negatives_3: 332.0000 - val_false_positives_3: 413.0000
# Epoch 8/20
# 98/98 [==============================] - ETA: 0s - loss: 0.2617 - binary_accuracy: 0.9062 - false_negatives_3: 1149.0000 - false_positives_3: 1197.0000
# Epoch 8: val_loss did not improve from 0.33714
# 98/98 [==============================] - 3s 25ms/step - loss: 0.2617 - binary_accuracy: 0.9062 - false_negatives_3: 1149.0000 - false_positives_3: 1197.0000 - val_loss: 0.3566 - val_binary_accuracy: 0.8510 - val_false_negatives_3: 330.0000 - val_false_positives_3: 415.0000
# Epoch 9/20
# 98/98 [==============================] - ETA: 0s - loss: 0.2497 - binary_accuracy: 0.9093 - false_negatives_3: 1126.0000 - false_positives_3: 1141.0000
# Epoch 9: val_loss did not improve from 0.33714
# 98/98 [==============================] - 2s 23ms/step - loss: 0.2497 - binary_accuracy: 0.9093 - false_negatives_3: 1126.0000 - false_positives_3: 1141.0000 - val_loss: 0.3803 - val_binary_accuracy: 0.8430 - val_false_negatives_3: 441.0000 - val_false_positives_3: 344.0000
# Epoch 9: early stopping
# 20/20 [==============================] - 2s 29ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 331.0, Number of ones incorrectly classified: 387.0
# Sample ratio for positives: 0.5389972144846796, Sample ratio for negatives:0.4610027855153203
# Starting training with 29997 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 118/118 [==============================] - ETA: 0s - loss: 0.3056 - binary_accuracy: 0.8819 - false_negatives_4: 1727.0000 - false_positives_4: 1815.0000
# Epoch 1: val_loss did not improve from 0.33714
# 118/118 [==============================] - 18s 101ms/step - loss: 0.3056 - binary_accuracy: 0.8819 - false_negatives_4: 1727.0000 - false_positives_4: 1815.0000 - val_loss: 0.3489 - val_binary_accuracy: 0.8478 - val_false_negatives_4: 402.0000 - val_false_positives_4: 359.0000
# Epoch 2/20
# 118/118 [==============================] - ETA: 0s - loss: 0.2867 - binary_accuracy: 0.8920 - false_negatives_4: 1568.0000 - false_positives_4: 1672.0000
# Epoch 2: val_loss did not improve from 0.33714
# 118/118 [==============================] - 5s 38ms/step - loss: 0.2867 - binary_accuracy: 0.8920 - false_negatives_4: 1568.0000 - false_positives_4: 1672.0000 - val_loss: 0.3517 - val_binary_accuracy: 0.8478 - val_false_negatives_4: 437.0000 - val_false_positives_4: 324.0000
# Epoch 3/20
# 118/118 [==============================] - ETA: 0s - loss: 0.2771 - binary_accuracy: 0.8967 - false_negatives_4: 1486.0000 - false_positives_4: 1612.0000
# Epoch 3: val_loss did not improve from 0.33714
# 118/118 [==============================] - 3s 24ms/step - loss: 0.2771 - binary_accuracy: 0.8967 - false_negatives_4: 1486.0000 - false_positives_4: 1612.0000 - val_loss: 0.3815 - val_binary_accuracy: 0.8452 - val_false_negatives_4: 203.0000 - val_false_positives_4: 571.0000
# Epoch 4/20
# 118/118 [==============================] - ETA: 0s - loss: 0.2660 - binary_accuracy: 0.8997 - false_negatives_4: 1515.0000 - false_positives_4: 1494.0000
# Epoch 4: val_loss did not improve from 0.33714
# 118/118 [==============================] - 3s 22ms/step - loss: 0.2660 - binary_accuracy: 0.8997 - false_negatives_4: 1515.0000 - false_positives_4: 1494.0000 - val_loss: 0.4305 - val_binary_accuracy: 0.8318 - val_false_negatives_4: 153.0000 - val_false_positives_4: 688.0000
# Epoch 5/20
# 118/118 [==============================] - ETA: 0s - loss: 0.2562 - binary_accuracy: 0.9060 - false_negatives_4: 1401.0000 - false_positives_4: 1418.0000
# Epoch 5: val_loss did not improve from 0.33714
# 118/118 [==============================] - 3s 24ms/step - loss: 0.2562 - binary_accuracy: 0.9060 - false_negatives_4: 1401.0000 - false_positives_4: 1418.0000 - val_loss: 0.3578 - val_binary_accuracy: 0.8434 - val_false_negatives_4: 313.0000 - val_false_positives_4: 470.0000
# Epoch 5: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.3359452188014984, 'binary_accuracy': 0.8564000129699707, 'false_negatives_3': 331.0, 'false_positives_3': 387.0}
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Conclusion
#
# Active Learning is a growing area of research. This example demonstrates the cost-efficiency
# benefits of using Active Learning, as it eliminates the need to annotate large amounts of
# data, saving resources.
#
# The following are some noteworthy observations from this example:
#
# 1. We only require 30,000 samples to reach the same (if not better) scores as the model
# trained on the full datatset. This means that in a real life setting, we save the effort
# required for annotating 10,000 images!
# 2. The number of false negatives and false positives are well balanced at the end of the
# training as compared to the skewed ratio obtained from the full training. This makes the
# model slightly more useful in real life scenarios where both the labels hold equal
# importance.
#
# For further reading about the types of sampling ratios, training techniques or available
# open source libraries/implementations, you can refer to the resources below:
#
# 1. [Active Learning Literature Survey](http://burrsettles.com/pub/settles.activelearning.pdf) (Burr Settles, 2010).
# 2. [modAL](https://github.com/modAL-python/modAL): A Modular Active Learning framework.
# 3. Google's unofficial [Active Learning playground](https://github.com/google/active-learning).
